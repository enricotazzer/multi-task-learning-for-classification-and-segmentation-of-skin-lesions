# %% [markdown]
# <a href="https://colab.research.google.com/github/enricotazzer/multi-task-learning-for-classification-and-segmentation-of-skin-lesions/blob/main/prova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ciao bella")
# Out:
# ciao bella
